# %%
info= dbutils.fs.ls('abfss://source@storageaccountproject1.dfs.core.windows.net')
tables = []
for table in info:
    if table.name != "checkpoints/":
        tables.append(table.name.strip('/'))
display(tables)

# %%
import json
dbutils.jobs.taskValues.set(key = "tables", value = json.dumps(tables))
print(f"tables: {tables}")
